# %% [markdown]
# # MBA FIAP Inteligência Artificial & Machine Learning
#
# ## Visão Computacional: Análise de Imagens Médicas
#
# > Atenção: este notebook foi desenhado para funcionar no **Google Collab**. Se pretende executar localmente prefira a versão local deste notebook, sem o sufixo ```-collab```.
#
#
# ## 1. Introdução
#
# As tecnologias de imagens médicas estão cada vez mais integradas aos sitemas de visão computacional, incluindo as imagens de raio-x.
#
# Modelos de equipamentos modernos geram imagens digitais deste tipo de exame, proporcionando análises mais completas e menos _ad-hoc_, com isso algumas pré-análises podem ser realizadas por aplicações baseadas em inteligência artificial para confirmar ou sugerir diagnósticos ao profissional responsável pelo exame.
#
# No campo dos diagósticos por raios-x, a pnenumonia é uma das enfermidades onde seu uso é um dos mais aplicados para determinar o curso de tratamento.
#
# <p align="center">
#     <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/NORMAL2-IM-1422-0001.jpeg?raw=1">
# </p>
#
# ## 2. Instruções
#
# Este projeto final tem como objetivo explorar os conhecimentos adquiridos nas aulas práticas.
#
# Por meio de uma trilha guiada, iremos constuir um modelo que seja capaz de classificar imagens de raio-x para determinar se a determinada pessoa está com alguma condição que necessita maiores cuidados.
#
# De acordo com as imagens disponíveis para o treinamento e validação, será de critério do grupo selecionar as quantidades ideais ou até mesmo pré-processar as imagens para obter o melhor resultado, nos principais indicadores de performance, como precisão, sensibilidade e pontuação F1.
#
# Este projeto poderá ser feita por grupos de até 4 pessoas.
# Caso este projeto seja substitutivo, deverá ser realizado por apenas uma pessoa.
#
# | Nome dos Integrantes     | RM            | Turma |
# | :----------------------- | :------------- | :-----: |
# | Daniel Pinto Rodrigues Evo | RM 336065     | `10IA` |
# | Danilo Silva de Oliveira   | RM 335665     | `10IA` |
# | Flavio Henrique Contreras  | RM 335531     | `10IA` |
# | Rodnei Macrini Cimidamore  | RM 335512     | `10IA` |
#
# Por ser um projeto guiado, fique atento quando houver as marcações **Implementação** indica que é necessário realizar alguma implementação em Python no bloco a seguir onde há a inscrição ```##IMPLEMENTAR``` e **Resposta** indica que é esperado uma resposta objetiva relacionado a algum questionamento.
#
# **Cada grupo pode utilizar nas respostas objetivas quaisquer itens necessários que enriqueçam seu ponto vista, como gráficos, fotos e, até mesmo, trechos de código-fonte.**
#
# Pode-se utilizar quantos blocos forem necessários para realizar determinadas implementações ou utilizá-las para justificar as respostas. Não é obrigatório utilizar somente o bloco indicado.
#
# Ao final não se esqueça de subir os arquivos do projeto nas contas do GitHub de cada membro, ou subir na do representante do grupo e os membros realizarem o fork do projeto.
#
# A avaliação terá mais ênfase nos seguintes tópicos de desenvolvimento do projeto:
#
# 1. __Pré-Processamento__
# 2. __Classificação__
# 3. __Performance__
# 4. __Conclusões Finais__

# %% [markdown]
# ## 3.1 Detalhe do problema: a pneunomia
#
# Fonte: [artigo](https://drauziovarella.uol.com.br/doencas-e-sintomas/pneumonia) do Dr. Drauzio Varella.
#
# Pneumonias são infecções que se instalam nos pulmões, órgãos duplos localizados um de cada lado da caixa torácica. Podem acometer a região dos alvéolos pulmonares onde desembocam as ramificações terminais dos brônquios e, às vezes, os interstícios (espaço entre um alvéolo e outro).
#
# Basicamente, pneumonia é provocada pela penetração de um agente infeccioso ou irritante (bactérias, vírus, fungos e por reações alérgicas) no espaço alveolar, onde ocorre a troca gasosa. Esse local deve estar sempre muito limpo, livre de substâncias que possam impedir o contato do ar com o sangue.
#
# Exame clínico, auscultação dos pulmões e radiografias de tórax são recursos essenciais para o diagnóstico de pneumonia.
#
# <p align="center">
#     <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/pneumonia.jpeg?raw=1">
# </p>

# %% [markdown]
# ## 3.2 Diagnóstico por raio-x

# %% [markdown]
# O exame de raio-x traz diferenças em cada tipo de diagnóstico, sendo considerado os seguintes grupos de análise: **normal** (ou controle) onde não há nenhuma condição de infeção, **bacterial pneumonia** (pneumonia bacteriana) que representa a condição de infecção bacteriana e **viral pneumonia** que indica a condição de infecção vira.

# %% [markdown]
# <p align="center">
# <img src="https://github.com/michelpf/fiap-ml-visao-computacional-capstone-alternative/blob/master/projeto-final/imagens/raiox.png?raw=1" height="60%" width="60%">
# </p>

# %% [markdown]
# As imagens de controle não são mais brancas ao centro que é onde fica o coração. Já nas imagens com pneumonia é possível notar regiões brancas ao redor dos pulmões, que é como o exame identifica as secreções responsáveis pela infeçcão.
#
# Quando mais regiões brancas ao redor do pulmão mais severa é a inflamação e menos se observa dos detalhes dos pulmões, ficando um pouco esmaecido diante desta condição.

# %% [markdown]
# ## 4.1 Problema
#
# Construir um classificador utilizando _transfer learning_ para identificar as seguintes classes: **controle**, **pneumonia bacteriana** e **pneumonia viral**.
#
# Para construir este classificador, utilize o dataset do [Kaggle Chest Ray Pneumonia](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) e organize os dados de forma a separar em cada uma das classes que já estão definidas no diretório ```raiox```, sendo ```controle``` para as imagens normais (sem inflamação), ```bacteria``` para as imagens de pneumonia bacteriana e ```viral``` para as imagens de pneumonia viral.
#
# Determine a quantidade de imagens a serem treinadas e validadas. Utiliza pelo menos, 100 imagens para cada classe.
#
# Compare os resultados com pelo menos 3 classificadores, obtendo os valores de **precisão (precision)**, **sensibilidade (recall)** e **pontuação F1 (F1 Score)**. No guia abaixo, foi indicado os seguintes modelos: ResNet50, VGG16 e VGG19.
#
# >Importante: a escolha do número de imagens devem ser o suficiente para alcançar o valor de **precisão** mínima de 70%.
# Note que as imagens de pneumonia bacteria e viral estão misturadas dentro da pasta ```PNEUMONIA```. É necessário separar as imagens manualmente tendo como base o sufixo. As imagens que terminal com ```_virus``` se referem a pneumoria viral e as que terminam com ```_bacteria``` se referem a pneumonia bacteriana.
#
# A construção do modelo será utilizada o framework Keras.

# %% [markdown]
# **Pergunta**: Qual o número de imagens que foram selecionadas para cada classe?

# %% [markdown]
# **Resposta**: Utilizamos as seguintes quantidades de imagens da base Kaggle:<br>
# > 1ª) Para a Classe <b>Controle (Normal)</b> foram utilizadas <b>800</b> imagens normais;<br>
# > 2ª) Para a Classe <b>Pneumonia Bacteriana</b> foram utilizadas <b>800</b> imagens bacterianas;<br>
# > 3ª) Para a Classe <b>Pneumonia Viral</b> foram utilizadas <b>800</b> imagens virais.

# %% [markdown]
# ## 4.2 Componentes obrigatórios
#
# Todas as bibliotecas já estão instaladas no Google Colab.
#
# * Keras
# * Tensorflow
# * Pillow
# * Matplotlib

# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

from tensorflow.keras.models import Sequential, load_model, model_from_json
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50, VGG19
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import Model, layers
from tensorflow.keras import optimizers

import tensorflow.keras.backend as K

# %% [markdown]
# ## 4.3 Carregando imagens de treinamento e validação
#
# Selecione a melhor divisão entre dados de treinamento e validação. O número deverá ser representado em número fracionário, 5% equivale a 0.05, por exemplo.

# %% [markdown]
# > Você pode _montar_ o drive do Google Drive se precisar e quiser armazenar as imagens nesta plataforma. Como o Colab é efêmero, se você copiar os arquivos para o ambiente eles serão apagados depois do fim da sessão. Acesse [esta](https://medium.com/@maxwellcsm/colaboratory-acessando-os-arquivos-do-google-drive-d08ef9157dbf) referência para saber mais como o recurso funciona, inclusive recomenda-se essa abordagem de montar o próprio Google Drive.
#
# Se não for utilizar o Google Drive, crie as pastas que serão utilizadas para armazenar as imagens.

# %% [markdown]
# ### 4.3.1 Utilizando Google Drive
#
# Se usar o Google Drive para armazenar as imagens utilize o comando abaixo para montar seu drive.
# Você pode navegar pelas pastas pelo painel ao lado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### 4.3.2 Utilizando o armazenamento efêmero
#
# Se optar pelo armazenamento efêmero você precisa enviar os arquivos de imagens (arrastar e soltar) para as pastas que deverão ser criadas pelo comando a seguir.

# %%
# !mkdir raiox/
# !mkdir raiox/normal
# !mkdir raiox/pneumonia_bacteriana
# !mkdir raiox/pneumonia_viral

# %% [markdown]
# Defina o nome da pasta onde contém as sub-pastas referente aos 3 tipos de classe. Se optar pelo armazenamento efêmero a pasta será ```raiox```. Se optar pelo Goolge Drive, indique o caminho da pasta.

# %%
## IMPLEMENTE
divisao_treino_validacao = 0.10 # 10% para testes
nome_pasta_raiz_imagens = '/content/drive/My Drive/raiox' #imagem que foram utilizadas

# %% [markdown]
# O caminho abaixo da pasta ```raiox``` pode ser alterado caso você opte por utilizar uma pasta específica do seu Google Drive. Neste caso, certifique que dentro delas tem as sub-pastas referentes as imagens normal, pneumonia bacteriana e viral.

# %%
train_datagen = ImageDataGenerator(validation_split=divisao_treino_validacao)

train_generator = train_datagen.flow_from_directory(
    nome_pasta_raiz_imagens,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="training")
# Out:
# Found 2160 images belonging to 3 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    nome_pasta_raiz_imagens,
    batch_size=32,
    class_mode="categorical",
    color_mode="rgb",
    target_size=(224,224),
    subset="validation")
# Out:
# Found 240 images belonging to 3 classes.

# %%
train_generator.class_indices, val_generator.class_indices
# Out:
# ({'bacteriana': 0, 'normal': 1, 'viral': 2},
#  {'bacteriana': 0, 'normal': 1, 'viral': 2})

# %% [markdown]
# ## 4.4 Modelos de transfer learning
#
# O Keras já possui classes especializadas para os seguintes modelos de deep-learning treinados com o conjunto de dados [ImageNet](http://www.image-net.org/):
#
# * Xception
# * VGG16
# * VGG19
# * ResNet50
# * InceptionV3
# * InceptionResNetV2
# * MobileNet
# * DenseNet
# * NASNet
# * MobileNetV2
#
# Mais detalhes, veja na [documentação do Keras](https://keras.io/applications/).

# %% [markdown]
# Para este estudo, vamos utilizar para avaliação as seguintes arquiteturas: RestNet50, VGG15 e VGG19.

# %% [markdown]
# ## 4.5 Indicadores de desempenho
#
# O Keras não possui os indicadores de desempenho como precisão, sensibilidade e pontuação f1 por padrão, portanto precisamos implementar externamente.

# %%
def recall_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_score(y_true, y_pred):
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### 4.5.1 Arquitetura ResNet50

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do ResNet50? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**: Como resumimos logo abaixo:

# %% [markdown]
# ### Redes Residuais - ResNet50
#
# Primeiramente temos dois tipos principais de blocos são usados em um ResNet, dependendo principalmente se as dimensões de entrada/saída são iguais ou diferentes.<br>
# 1º Bloco de identidade:<br>
# >Este bloco por padrão usado em ResNets, corresponde ao caso em que a ativação de entrada (digamos a[l]) tem a mesma dimensão da ativação de saída (digamos a[l+2]). Abaixo é mostrado o caminho atalho "superior" e o caminho principal "inferior".<br>
# ><p align="center">
# ><img src="https://github.com/rodneimc/fiap-ml-visao-computacional/blob/master/images/BlocoIdentidadeResNet.jpeg?raw=1">
# ></p>
# >Abaixo um exemplo de uma função com o bloco de Identidade:<br>
# ><p align="center">
# <img src="https://github.com/rodneimc/fiap-ml-visao-computacional/blob/master/images/CodIdentidadeKeras.jpeg?raw=1">
# </p>
#
# 2º Bloco Convolucional:<br>
# >Quando as dimensões de entrada e saída não correspondem, adicionamos uma camada convolucional no caminho do atalho. O acordo é chamado de bloco convolucional.<br>
# ><p align="center">
# ><img src="https://github.com/rodneimc/fiap-ml-visao-computacional/blob/master/images/BlocoConvulacionalResNet.jpeg?raw=1">
# ></p>
# >Abaixo um exemplo de uma função com o bloco de Identidade:<br>
# ><p align="center">
# <img src="https://github.com/rodneimc/fiap-ml-visao-computacional/blob/master/images/CodConvulacionalKeras.jpeg?raw=1">
# </p>
#
# Com os blocos acima podemos construir uma ResNet muito profunda neste caso a ResNet50, logo abaixo:
# ><p align="center">
# ><img src="https://github.com/rodneimc/fiap-ml-visao-computacional/blob/master/images/ArquiteturaResNet50.jpeg?raw=1">
# ></p>
# >Vamos para os detalhes desta Arquitetura:<br>
# 1º - Estofamento zero: pads a entrada com um bloco de (3,3)<br>
# 2º - Estágio 1: A Convolução 2D tem 64 filtros de forma (7,7) e usa um passo de (2,2). Seu nome é "conv1". BatchNorm é aplicado ao eixo de canais da entrada. MaxPooling usa uma janela (3,3) e um passo (2,2).<br>
# 3º - Estágio 2: O bloco convolucional utiliza três conjuntos de filtros de tamanho 64x64x256, f=3, s=1 e o bloco é "a". Os 2 blocos de identidade utilizam três conjuntos de filtros de tamanho 64x64x256, f=3 e os blocos são "b" e "c".
# Estágio 3: O bloco convolucional utiliza três conjuntos de filtros de tamanho 128x128x512, f=3, s=2 e o bloco é "a". Os 3 blocos de identidade utilizam três conjuntos de filtros de tamanho 128x128x512, f=3 e os blocos são "b", "c" e "d".<br>
# 4º - Estágio 4: O bloco convolucional utiliza três conjuntos de filtros de tamanho 256x256x1024, f=3, s=2 e o bloco é "a". Os 5 blocos de identidade utilizam três conjuntos de filtros de tamanho 256x256x1024, f=3 e os blocos são "b", "c", "d", "e" e "f".<br>
# 5º - Estágio 5: O bloco convolucional utiliza três conjuntos de filtros de tamanho 512x512x2048, f=3, s=2 e o bloco é "a". Os 2 blocos de identidade utilizam três conjuntos de filtros de tamanho 256x256x2048, f=3 e os blocos são "b" e "c".<br>
# 6º - O Pooling Médio 2D usa uma janela de forma (2,2) e seu nome é "avg_pool".<br>
# 7º - O achatado não tem hiperparmetros ou nome.<br>
# 8º - A camada Totalmente Conectada (Densa) reduz sua entrada para o número de classes usando uma ativação softmax. Seu nome deve ser 'fc' + str(classes).<br>
# <br>

# %% [markdown]
# ### Conclusão sobre a <b>ResNet50</b>:
# A rede neural residual profunda com 50 camadas, tem a característica de deixar o treino mais eficiente, não são fáceis de implementar, pois são difíceis de treinar e podem conduzir ao desaparecimento de gradientes, fenômeno chamado de Gradientes de Desaparecimento.

# %% [markdown]
# A técnica de transfer learning consiste de utilizar o mesmo modelo e treiná-lo para outas imagens. Por tal motivo, excluímos a última camada para modelar com as classes que definimos, ou seja, **controle**, **bacteriana** e **viral**.

# %% [markdown]
# Informe a quantidade de classes a serem classificadas.

# %%
## IMPLEMENTE

qtde_classes = 3 # consideramos as 3 classes (NORMAL, VIRAL E BACTERIANA)

# %%
conv_base = ResNet50(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# ...
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %% [markdown]
# O número de épocas define quantas vezes o modelo irá treinar e validar o erro, assim ajustando os pesos para melhor convergência.
# Escolha o número adequado de épocas para alcançarmos pelo menos **70% de precisão de validação**.

# %%
## IMPLEMENTE

qtde_epocas = 12

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/12
# 5/5 [==============================] - 69s 14s/step - loss: 2.0440 - precision_score: 0.3617 - recall_score: 0.3562 - f1_score: 0.3589 - val_loss: 0.9245 - val_precision_score: 0.6576 - val_recall_score: 0.4563 - val_f1_score: 0.5364
# Epoch 2/12
# 5/5 [==============================] - 52s 10s/step - loss: 0.7506 - precision_score: 0.7212 - recall_score: 0.5500 - f1_score: 0.6234 - val_loss: 1.0192 - val_precision_score: 0.5901 - val_recall_score: 0.5000 - val_f1_score: 0.5408
# Epoch 3/12
# 5/5 [==============================] - 51s 10s/step - loss: 0.5993 - precision_score: 0.7787 - recall_score: 0.6687 - f1_score: 0.7164 - val_loss: 0.7594 - val_precision_score: 0.7401 - val_recall_score: 0.6562 - val_f1_score: 0.6952
# Epoch 4/12
# 5/5 [==============================] - 48s 10s/step - loss: 0.6897 - precision_score: 0.6893 - recall_score: 0.6438 - f1_score: 0.6653 - val_loss: 0.8745 - val_precision_score: 0.6278 - val_recall_score: 0.6062 - val_f1_score: 0.6168
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# Nesta execução com o <b>ResNet50</b>, podemos observar que no gráfico de perda (loss), executados nas 12 épocas, tanto para treino como para teste, estão com a tendência de serem descendentes e os gráficos de precisão, de sensibilidade e de pontuação f1, também executados nas 12 épocas, tanto para treino como para teste, estão com a tendência de serem ascendentes, portanto todos valores medidos, <i>estão convergindo bem</i>.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ```
# Epoch 12/12
# 5/5 [==============================] - 46s 9s/step - loss: 0.4016 - precision_score: 0.8444 - recall_score: 0.8188 - f1_score: 0.8312 - val_loss: 0.5127 - val_precision_score: 0.8217 - val_recall_score: 0.8062 - val_f1_score: 0.8138```
#
# Chegamos aos seguintes valores:<br>
# Precisão de <b>82,17%</b>;<br>
# Sensibilidade de <b>80,62%</b>;<br>
# Pontuação de validação de <b>81,38%</b>.<br>

# %% [markdown]
# ### 4.5.2 Arquitetura VGG16

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG16? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**: Como resumimos logo abaixo:

# %% [markdown]
# ### Rede Convolucional de Classificação e Detecção - VGG16
#
#
# Primeiramente, VGG16 é um modelo de rede neural convolucional proposto por K. Simonyan e A. Zisserman da Universidade de Oxford no artigo "Redes Convolucionais Muito Profundas para Reconhecimento de Imagem em Larga Escala".<br>
# ><p align="center">
# ><img src="https://github.com/rodneimc/fiap-ml-visao-computacional/blob/master/images/Camadasvgg16.png?raw=1"><br>
#
# O modelo alcança 92,7% de precisão de teste top-5 no ImageNet, que é um conjunto de dados de mais de 14 milhões de imagens pertencentes a 1000 classes. Foi um dos modelos famosos submetidos ao ILSVRC-2014.<br>
#
# ### A arquitetura com o VGG16
# ><p align="center">
# ><img src="https://github.com/rodneimc/fiap-ml-visao-computacional/blob/master/images/vgg16-neural-network.jpg?raw=1"><br>
#
# A rede possui como camada inicial uma camada convolucional de tamanho 224x224. A entrada é então transmitida a partir de uma série de camadas convolucionais onde as camadas seguintes vão reduzindo o número de entradas e alternando entre camadas de max-pooling e convolucionais, até que ao final são utilizadas camadas totalmente conectadas com uma função de ativação Softmax para gerar a saída final.
#
# Fonte: https://neurohive.io/en/popular-networks/vgg16/

# %% [markdown]
# ### Conclusão sobre a <b>VGG16</b>:
# O VGG16 superou significativamente a geração anterior de modelos nas competições ILSVRC-2012 e ILSVRC-2013 e é benéfica para a precisão de classificação, mas tendo 2 desvantagens principáis: é muito, mas muito lenta para treinar e pesa muito na arquitetura de rede tanto para espaço em disco com para largura de banda.

# %%
conv_base = VGG16(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# ...
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/12
# 5/5 [==============================] - 145s 29s/step - loss: 0.5611 - precision_score: 0.7885 - recall_score: 0.7688 - f1_score: 0.7785 - val_loss: 0.7518 - val_precision_score: 0.7204 - val_recall_score: 0.6938 - val_f1_score: 0.7068
# Epoch 2/12
# 5/5 [==============================] - 146s 29s/step - loss: 0.4689 - precision_score: 0.8405 - recall_score: 0.8250 - f1_score: 0.8326 - val_loss: 0.7545 - val_precision_score: 0.7020 - val_recall_score: 0.6750 - val_f1_score: 0.6880
# Epoch 3/12
# 5/5 [==============================] - 148s 30s/step - loss: 0.4164 - precision_score: 0.8276 - recall_score: 0.8062 - f1_score: 0.8168 - val_loss: 0.7148 - val_precision_score: 0.7428 - val_recall_score: 0.6938 - val_f1_score: 0.7173
# Epoch 4/12
# 5/5 [==============================] - 146s 29s/step - loss: 0.5115 - precision_score: 0.8474 - recall_score: 0.8313 - f1_score: 0.8392 - val_loss: 0.8858 - val_precision_score: 0.7071 - val_recall_score: 0.6875 - val_f1_score: 0.6970
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# Nesta execução com o <b>VGG16</b>, podemos observar que no gráfico de perda (loss), executados nas 12 épocas, tanto para treino como para teste, estão com a tendência aparentemente de serem ascendentes. Para os gráficos de precisão, de sensibilidade e de pontuação f1, também executados nas 12 épocas, tanto para treino como para teste, podemos ver a mesma tendência, portanto todos valores medidos <i>não estão convergindo bem</i>.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ```Epoch 12/12 <br>
# 5/5 [==============================] - 145s 29s/step - loss: 0.3441 - precision_score: 0.8625 - recall_score: 0.8625 - f1_score: 0.8625 - val_loss: 0.6766 - val_precision_score: 0.7733 - val_recall_score: 0.7437 - val_f1_score: 0.7579```
# <br>
# Chegamos aos seguintes valores:<br>
# Precisão de <b>77,33%</b>;<br>
# Sensibilidade de <b>74,37%</b>;<br>
# Pontuação de validação de <b>75,79%</b>.<br>

# %% [markdown]
# ### 4.5.3 Arquitetura VGG19

# %% [markdown]
# **Pergunta**: Explique como é constituída a arquitetura do VGG19? *Utilize, se necessário, gráficos, projetos que utilizam essa arquitetura. Detalhe também sua topologia em camadas e mostre quais as situações essa arquitetura pode ter mais êxito e quais cenários não tem.*

# %% [markdown]
# **Resposta**:

# %% [markdown]
# A rede VGG introduzida por Simonyan e Zisserman no seu artigo de 2014, "Very Deep Convolutional Networks for Large Scale Image Recognition", é caracterizada pela sua simplicidade, usando apenas convoluções 3 × 3 sobrepostas em profundidade crescente. A redução de volume de dados é conseguida através de maxpooling. Duas camadas fullyconnected, cada uma com 4096 nós são acompanhadas de um classificador softmax [Simonyan and Zisserman, 2014]. Os numeros 16 e 19 representam o número das camadas com pesos na rede. Algumas desvantagens das VGGNets sao a morosidade do treino e a largura da arquitetura de pesos. Antecipamos assim a conclusão por ser parecida com quanto ao problema de espaço em disco e processamentoi, onde as profundidades e número de nodos fully-connected da VGG16 consomem mais de 533MB e da VGG19 consomem mais de 574MB, o que torna a implantacão (deploy) destas redes complicadas.
#
# ><p align="center">
# ><img src="https://github.com/rodneimc/fiap-ml-visao-computacional/blob/master/images/Architecture-of-the-FCN-VGG19-adapted-from-Long-et-al-2015-which-learns-to-combine.png?raw=1"><br>
#
# A VGG19 possui arquitetura similar à VGG 16 com o diferencial sendo o número superior de camadas convolucionais no layer de max-pooling.

# %%
conv_base = VGG19(include_top=False)

for layer in conv_base.layers:
    layer.trainable = False
# Out:
# ...
# 80142336/80134624 [==============================] - 0s 0us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x) 

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/12
# 5/5 [==============================] - 173s 35s/step - loss: 3.9331 - precision_score: 0.3063 - recall_score: 0.3063 - f1_score: 0.3062 - val_loss: 2.7164 - val_precision_score: 0.3591 - val_recall_score: 0.3562 - val_f1_score: 0.3576
# Epoch 2/12
# 5/5 [==============================] - 185s 37s/step - loss: 1.6999 - precision_score: 0.5742 - recall_score: 0.5500 - f1_score: 0.5618 - val_loss: 1.7009 - val_precision_score: 0.5194 - val_recall_score: 0.4938 - val_f1_score: 0.5060
# Epoch 3/12
# 5/5 [==============================] - 183s 37s/step - loss: 1.2386 - precision_score: 0.6423 - recall_score: 0.6062 - f1_score: 0.6235 - val_loss: 1.8549 - val_precision_score: 0.4518 - val_recall_score: 0.4500 - val_f1_score: 0.4509
# Epoch 4/12
# 5/5 [==============================] - 183s 37s/step - loss: 1.2885 - precision_score: 0.6097 - recall_score: 0.5875 - f1_score: 0.5983 - val_loss: 1.2466 - val_precision_score: 0.6007 - val_recall_score: 0.5750 - val_f1_score: 0.5874
# ...

# %% [markdown]
# Um modelo que converge bem possui o gráfico de perda (*loss*) descendente e os gráfico de precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*) em acendente.

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **Pergunta**: Avalie os gráficos de perda (*loss*), precisão (*precision*), sensibilidade (*recall*) e pontuação f1 (*f1 score*)  e explique o comportamento de ambos no que tange a convergência do modelo.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# Nesta execução com o <b>VGG19</b>, podemos observar que no gráfico de perda (loss), executados nas 12 épocas, tanto para treino como para teste, estão com a tendência de serem descendentes e os gráficos de precisão, de sensibilidade e de pontuação f1, também executados nas 12 épocas, tanto para treino como para teste, estão com a tendência de serem ascendentes, portanto todos valores medidos, <i>estão convergindo bem</i>.

# %% [markdown]
# **Pergunta**: Quais são os valores de **precisão (precision)**, **sensibilidade (recall)** de validação?
#
# *Estes valores são exibidos durante o treinamento, utilize a última saída, exemplo:*
#
# ```
# Epoch 10/10 [==============================] - 45s 9s/step - loss: 0.1234 - precision_score: 0.9742 - recall_score: 0.9683 - f1_score: 0.9712 - val_loss: 0.8819 - val_precision_score: 0.6912 - val_recall_score: 0.5649 - val_f1_score: 0.6216```
#
# No caso acima, o valor de precisão, sensibilidade e pontuação de validação são, respectivamente, 69,12%, 56,49% e 62,16%.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# ```Epoch 12/12 <br>
# 5/5 [==============================] - 184s 37s/step - loss: 0.5993 - precision_score: 0.7827 - recall_score: 0.7688 - f1_score: 0.7756 - val_loss: 0.7658 - val_precision_score: 0.7378 - val_recall_score: 0.7250 - val_f1_score: 0.7312```
#
# Chegamos aos seguintes valores:<br>
# Precisão de <b>73,78%</b>;<br>
# Sensibilidade de <b>72,50%</b>;<br>
# Pontuação de validação de <b>73,12%</b>.<br>

# %% [markdown]
# ## 4.6 Compartivo de arquiteturas
#
# Preencha a tabela abaixo com os valores dos indicadores de performance apresentados.
#
# _O cálculo do F1-Score é dado por 2 * (Precisão * Sensibilidade) / (Precisão + Sensibilidade)._

# %% [markdown]
# | Modelo   | Precisão (*Precision*) | Sensibilidade (*Recall*) | F1-Score |
# |----------|----------|---------------|----------|
# | ResNet50 | 82,17%   | 80,62%        | 81,38%   |
# | VGG16    | 77,33%   | 74,37%        | 75,79%   |
# | VGG19    | 73,78%   | 72,50%        | 73,12%   |

# %% [markdown]
# ## 4.7 Conclusões
#
# Analise os resultados da tabela de indicadores do comparativo de arquiteturas e explique os principais motivos pelos quais cada modelo obteve cada resultado.

# %% [markdown]
# **Resposta**:
# Analisando os resultados da tabela, podemos perceber que a ResNet50 obteve resultado superior às outras. Quando utilizamos redes com muitas camadas, a existências destas multiplas camadas pode atrapalhar na habilidade de treinar a rede para performar bem nos dados de teste, uma vez que fica difícil para a rede aprender mais pesos. A ResNet50 é uma rede que utiliza blocos residuais, que auxiliam no treinamento para evitar esta perda de performance, fator que influencia em sua performance superior as outras redes. Já considerando somente as redes VGG16 e VGG19, podemos ver que a existências de mais camadas acabou afetando negativamente a performance da VGG19 em comparação a VGG16.

# %% [markdown]
# ## 4.8 Abordagem adicional (obrigatório)
#
# Considerando os outros classificadores, escolha outro que ainda não foi utilizado, implemente abaixo. Ao final compare os resultados e explique os resultados.
#
# _Não se esquece de utilizar as importações adequadas para cada modelo.
# A forma de implementação deve respeitar as mesmas condições como valor de split e quantidade de imagens para poder comparar os modelos._

# %%
#IMPLEMENTE
from tensorflow.keras.applications import NASNetLarge
conv_base = NASNetLarge(include_top=False)

for layer in conv_base.layers:
  layer.trainable = False
# Out:
# ...
# 343613440/343610240 [==============================] - 3s 0us/step

# %%
x = conv_base.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x)

predictions = layers.Dense(qtde_classes, activation='softmax')(x)
model = Model(conv_base.input, predictions)

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, 331, 331, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 165, 165, 96) 2592        input_4[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 165, 165, 96) 384         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 165, 165, 42) 4032        activation[0][0]
# ...

# %%
optimizer = optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[precision_score, recall_score, f1_score])

# %%
history = model.fit(train_generator, epochs=qtde_epocas, validation_steps=5, steps_per_epoch=5, 
                    validation_data=val_generator)
# Out:
# Epoch 1/12
# 5/5 [==============================] - 169s 34s/step - loss: 0.6435 - precision_score: 0.7596 - recall_score: 0.6875 - f1_score: 0.7216 - val_loss: 0.5974 - val_precision_score: 0.8124 - val_recall_score: 0.7125 - val_f1_score: 0.7584
# Epoch 2/12
# 5/5 [==============================] - 169s 34s/step - loss: 0.6614 - precision_score: 0.7854 - recall_score: 0.7437 - f1_score: 0.7635 - val_loss: 0.5955 - val_precision_score: 0.7951 - val_recall_score: 0.7312 - val_f1_score: 0.7612
# Epoch 3/12
# 5/5 [==============================] - 167s 33s/step - loss: 0.4936 - precision_score: 0.8417 - recall_score: 0.8000 - f1_score: 0.8202 - val_loss: 0.6463 - val_precision_score: 0.6947 - val_recall_score: 0.6562 - val_f1_score: 0.6748
# Epoch 4/12
# 5/5 [==============================] - 167s 33s/step - loss: 0.5304 - precision_score: 0.8009 - recall_score: 0.7812 - f1_score: 0.7908 - val_loss: 0.6056 - val_precision_score: 0.7737 - val_recall_score: 0.6812 - val_f1_score: 0.7238
# ...

# %%
# Exibindo dados de Precisão
plt.plot(history.history['precision_score'])
plt.plot(history.history['val_precision_score'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Sensibilidade
plt.plot(history.history['recall_score'])
plt.plot(history.history['val_recall_score'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de F1 Score
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Exibindo dados de Perda
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### 4.8.1 Conclusões sobre a abordagem adicional
#
# Como seu modelo performou em comparação com os demais modelos anteriores? Justifique sua resposta levando em consideração a arquitetura respectiva.

# %% [markdown]
# **Resposta**:

# %% [markdown]
# Na execução com o <b>NASNetLarge</b>, podemos observar que no gráfico de perda (loss), executados nas 12 épocas, tanto para treino como para teste, estão com a leve tendência de serem descendentes e os gráficos de precisão, de sensibilidade e de pontuação f1, também executados nas 12 épocas, tanto para treino como para teste, estão com a leve tendência de serem ascendentes, portanto todos valores medidos, <i>não estão convergindo tão bem assim</i>.

# %% [markdown]
# ```Epoch 12/12 <br>
# 5/5 [==============================] - 170s 34s/step - loss: 0.4723 - precision_score: 0.8397 - recall_score: 0.7875 - f1_score: 0.8126 - val_loss: 0.6124 - val_precision_score: 0.7734 - val_recall_score: 0.7125 - val_f1_score: 0.7408```
#
# Chegamos aos seguintes valores:<br>
# Precisão de <b>77,34%</b>;<br>
# Sensibilidade de <b>71,25%</b>;<br>
# Pontuação de validação de <b>74,08%</b>.<br>

# %% [markdown]
# | Modelo      | Precisão (*Precision*) | Sensibilidade (*Recall*)    | F1-Score |
# |-------------|----------|-------------|----------|
# | ResNet50    | 82,17%   | 80,62%      | 81,38%   |
# | VGG16       | 77,33%   | 74,37%      | 75,79%   |
# | VGG19       | 73,78%   | 72,50%      | 73,12%   |
# | NASNetLarge | 77,34%   | 71,25%      | 74,08%   |

# %% [markdown]
# Obs: mesmo a <b>NASNetLarge</b> ficando com uma precisão melhor que a <b>VGG16</b>, ainda assim a sensibilidade e o F1 Score não são melhores, com reflexo sendo mostrados pelos gráficos que não estão convergindo bem.
